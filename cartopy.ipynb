# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from cartopy.feature import NaturalEarthFeature, LAND, COASTLINE
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.io import shapereader

# %%
earth = NaturalEarthFeature(category = 'cultural', name = 'admin_0_map_units', scale = '110m')

# %%
earth

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
ax.add_feature(earth, facecolor = "red")

# %%
filename = shapereader.natural_earth(resolution='110m', category='cultural', name='admin_0_map_units')

# %%
filename
# Out:
# '/research-home/qread/.local/share/cartopy/shapefiles/natural_earth/cultural/ne_110m_admin_0_map_units.shp'

# %%
reader = shapereader.Reader(filename)
countries = reader.records()
country = next(countries)

# %%
country
# Out:
# <Record: <shapely.geometry.multipolygon.MultiPolygon object at 0x7fbd6fabf160>, {'featurecla': 'Admin-0 map unit', 'scalerank': 1, 'LABELRANK': 6, 'SOVEREIGNT': 'Fiji', 'SOV_A3': 'FJI', 'ADM0_DIF': 0, 'LEVEL': 2, 'TYPE': 'Sovereign country', 'ADMIN': 'Fiji', 'ADM0_A3': 'FJI', 'GEOU_DIF': 0, 'GEOUNIT': 'Fiji', 'GU_A3': 'FJI', 'SU_DIF': 0, 'SUBUNIT': 'Fiji', 'SU_A3': 'FJI', 'BRK_DIFF': 0, 'NAME': 'Fiji', 'NAME_LONG': 'Fiji', 'BRK_A3': 'FJI', 'BRK_NAME': 'Fiji', 'BRK_GROUP': None, 'ABBREV': 'Fiji', 'POSTAL': 'FJ', 'FORMAL_EN': 'Republic of Fiji', 'FORMAL_FR': None, 'NAME_CIAWF': 'Fiji', 'NOTE_ADM0': None, 'NOTE_BRK': None, 'NAME_SORT': 'Fiji', 'NAME_ALT': None, 'MAPCOLOR7': 5, 'MAPCOLOR8': 1, 'MAPCOLOR9': 2, 'MAPCOLOR13': 2, 'POP_EST': 920938.0, 'POP_RANK': 11, 'GDP_MD_EST': 8374.0, 'POP_YEAR': 2017, 'LASTCENSUS': 2007, 'GDP_YEAR': 2016, 'ECONOMY': '6. Developing region', 'INCOME_GRP': '4. Lower middle income', 'WIKIPEDIA': -99, 'FIPS_10_': 'FJ', 'ISO_A2': 'FJ', 'ISO_A3': 'FJI', 'ISO_A3
# ...
